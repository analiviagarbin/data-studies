# %% [markdown]
# Exploring lib requests

# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
r.json()
# Out:
# [{'id': '40332684576',
#   'type': 'PushEvent',
#   'actor': {'id': 149211966,
#    'login': 'astridmilan',
#    'display_login': 'astridmilan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/astridmilan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/149211966?'},
#   'repo': {'id': 831592863,
#    'name': 'astridmilan/proyec-4',
#    'url': 'https://api.github.com/repos/astridmilan/proyec-4'},
#   'payload': {'repository_id': 831592863,
#    'push_id': 19414971071,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '4fd7ed257ac31c20207becc9243c4878a9687be3',
#    'before': 'f591c3d48e3260a5a55be885165ea336e0364b29',
#    'commits': [{'sha': '4fd7ed257ac31c20207becc9243c4878a9687be3',
#      'author': {'email': '149211966+astridmilan@users.noreply.github.com',
#       'name': 'lovelaze'},
#      'message': 'Create controllers',
#      'distinct': True,
# ...

# %%
r = requests.get('https://api.github.com/versions')
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# ['2022-11-28']

# %%
r = requests.get('https://api.github.com/users/analiviagarbin')
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'login': 'analiviagarbin',
#  'id': 95146046,
#  'node_id': 'U_kgDOBavQPg',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/95146046?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/analiviagarbin',
#  'html_url': 'https://github.com/analiviagarbin',
#  'followers_url': 'https://api.github.com/users/analiviagarbin/followers',
#  'following_url': 'https://api.github.com/users/analiviagarbin/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/analiviagarbin/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/analiviagarbin/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/analiviagarbin/subscriptions',
#  'organizations_url': 'https://api.github.com/users/analiviagarbin/orgs',
#  'repos_url': 'https://api.github.com/users/analiviagarbin/repos',
#  'events_url': 'https://api.github.com/users/analiviagarbin/events{/privacy}',
# ...

# %%
r.url
# Out:
# 'https://api.github.com/users/analiviagarbin'

# %%
user = r.json()

# %%
print(
    user['name'],
    user['login'],
    user['public_repos'],
    user['created_at']
    )
# Out:
# Ana Lívia Magalhães Garbin analiviagarbin 18 2021-11-27T19:26:18Z
